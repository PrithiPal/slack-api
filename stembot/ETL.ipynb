# %%
import os 
import slack 
import time 
import pickle
import pandas as pd 
import numpy as np 
from typing import Dict, List
from pymongo import MongoClient
from parameters import * 
import re

# %%
df=pd.read_csv(STUDENTS_CSV,parse_dates=['Submission Time'])
df.head()
# Out:
#           Submission Time Paypal - Mode                         ...                         What do you want to learn most from participating in the Big Data Challenge?   How did you find out about the Big Data Challenge?
# 0  15 May 2020 @ 19:48 PM          live                         ...                          We feel that, for all of us, data analytics is...                                                    From advertisements online
# 1  15 May 2020 @ 17:24 PM          live                         ...                          We would like to learn new skills, network and...                             Faiq - a member of STEM fellowship program ref...
# 2  14 May 2020 @ 22:35 PM          live                         ...                          Sara: Data science is a field that I have been...                             LinkedIn! We love keeping an eye out for new e...
# 3  14 May 2020 @ 05:38 AM          live                         ...                          We want to increase our experience with academ...                                                                      A friend
# 4  14 May 2020 @ 05:24 AM          live                         ...                          1) How to critically analyze complex data and ...                                                 Let's Talk Science Newsletter
#
# [5 rows x 51 columns]

# %%
EMAIL_LIST=[]
def gather_email(row) : 
    
    if row['Email Address'] is not np.nan : 
        
        EMAIL_LIST.append(str(row['Email Address']))
    if row['Email Address.1'] is not np.nan: 
        EMAIL_LIST.append(str(row['Email Address.1']))
    if row['Email Address.2'] is not np.nan: 
        EMAIL_LIST.append(str(row['Email Address.2']))
    if row["Email Address.3"] is not np.nan : 
        EMAIL_LIST.append(str(row['Email Address.3']))
        
df.apply(gather_email,axis=1)

sample_file=open("student_invite_emails.txt","w")
sample_file.write(",".join(EMAIL_LIST))
sample_file.close()

# %%
df.columns.tolist()
# Out:
# ['Submission Time',
#  'Paypal - Mode',
#  'Paypal - Status',
#  'Paypal - Amount',
#  'Paypal - Currency',
#  'Paypal - Transaction ID',
#  'Name - First Name',
#  'Name - Last Name',
#  'Name - First Name.1',
#  'Name - Last Name.1',
#  'Name - First Name.2',
#  'Name - Last Name.2',
#  'Name - First Name.3',
#  'Name - Last Name.3',
#  'University',
#  'University.1',
#  'University.2',
#  'University.3',
#  'Year of University',
#  'Year of University.1',
#  'Year of University.2',
#  'Year of University.3',
#  'Program of Study',
#  'Program of Study.1',
#  'Program of Study.2',
#  'Program of Study.3',
#  'Age',
#  'Age.1',
#  'Age.2',
#  'Age.3',
#  'Ethnicity',
#  'Ethnicity.1',
#  'Ethnicity.2',
#  'Ethnicity.3',
#  'Gender Identity',
#  'Gender Identity.1',
#  'Gender Identity.2',
#  'Gender Identity.3',
#  'Email Address',
#  'Email Address.1',
#  'Email Address.2',
#  'Email Address.3',
#  'Experience in Data Science',
#  'Experience in Data Science.1',
#  'Experience in Data Science.2',
#  'Experience in Data Science.3',
#  'Do any team member identify as part of a population that is underrepresented in STEM fields? (ie indigenous, from a rural community, immigrant/refugee, visible minority, female, etc). If so, please indicate what you identify as',
#  'If selected "other", please specify',
#  'Please provide a summary of each team members research interests and/or their major',
#  'What do you want to learn most from participating in the Big Data Challenge? ',
#  'How did you find out about the Big Data Challenge?']
